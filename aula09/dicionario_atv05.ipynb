# %%
#Exercício 1

aluno = {
    "Nome": "Adriel",
    "Idade": 18,
    "Curso": "Ford Enter"
}
aluno["nota"] = 10
print(aluno)
# Out:
# {'Nome': 'Adriel', 'Idade': 18, 'Curso': 'Ford Enter', 'nota': 10}

# %%
#Exercício 2

produtos = {
    "Camisa Brasil": 499.90,
    "Camisa Corinthians": 279.89,
    "Camisa Real Madrid": 349.50
}

print("Preço Camisa Brasil:", produtos["Camisa Brasil"])
# Out:
# Preço Camisa Brasil: 499.9

# %%
#Exercício 3

produtos = {
    "Camisa Brasil": 499.90,
    "Camisa Corinthians": 279.89,
    "Camisa Real Madrid": 349.50
}

del produtos["Camisa Corinthians"]
print(produtos)
# Out:
# {'Camisa Brasil': 499.9, 'Camisa Real Madrid': 349.5}
