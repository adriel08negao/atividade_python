# %%
livros = [
    {"Título": "Arsène Lupin 813", "Autor:": "Maurice Leblanc", "Ano": "1910"},
    {"Título": "Psicopata Americano", "Autor:": "Bret Easton Ellis", "Ano": "1991"},
    {"Título": "O pequeno príncipe", "Autor:": "Antonie de Saint Exupéry", "Ano": "1943"}
]
for livros in livros:
    print("Título:", livro["título"])
    print("Autor:", livro["autor"])
    print("Ano:", livro["ano"])
    print("-" * 30)
