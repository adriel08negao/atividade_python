# %%
#Exercício 1

def divisao_segura(a, b):
    try:
        resultado = a / b
    except ZeroDivisionError:
        print("Erro: divisão por zero não é permitida.")
        return None
    else:
        return resultado
    finally:
        print("Operação de divisão realizada.")

# %%
#Exercício 2

produtos = {
    "Cubo mágico": 9.89
    "Bola futebol": 19.99
    "Lanterna": 14.99
}
